# %% [markdown]
# <a href="https://colab.research.google.com/github/prachi732/Data_Visualization/blob/master/Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
tips=sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.distplot(tips['total_bill'],kde=False,bins=30)

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='reg')

# %%
sns.pairplot(tips,hue='sex')

# %%
sns.kdeplot(tips['total_bill'])

# %%
sns.barplot(x='sex',y='total_bill',data=tips,estimator=np.std)

# %%
# counting occurences
sns.countplot(x='sex',data=tips)

# %%
sns.boxplot(x='day',y='total_bill',data=tips)

# %%
sns.violinplot(x='day',y='total_bill',data=tips)

# %% [markdown]
# **Heatmaps**

# %%
flights=sns.load_dataset('flights')

# %%
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
flights.tail()
# Out:
#      year      month  passengers
# 139  1960     August         606
# 140  1960  September         508
# 141  1960    October         461
# 142  1960   November         390
# 143  1960   December         432

# %%
tc=tips.corr()
tc
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tc,annot=True)

# %%
pt=flights.pivot_table(index='month',columns='year',values='passengers')
pt
# Out:
# year       1949  1950  1951  1952  1953  ...  1956  1957  1958  1959  1960
# month                                    ...
# January     112   115   145   171   196  ...   284   315   340   360   417
# February    118   126   150   180   196  ...   277   301   318   342   391
# March       132   141   178   193   236  ...   317   356   362   406   419
# April       129   135   163   181   235  ...   313   348   348   396   461
# May         121   125   172   183   229  ...   318   355   363   420   472
# June        135   149   178   218   243  ...   374   422   435   472   535
# July        148   170   199   230   264  ...   413   465   491   548   622
# August      148   170   199   242   272  ...   405   467   505   559   606
# September   136   158   184   209   237  ...   355   404   404   463   508
# October     119   133   162   191   211  ...   306   347   359   407   461
# November    104   114   146   172   180  ...   271   305   310   362   390
# ...

# %%
sns.heatmap(pt,cmap='magma',linecolor='white',linewidths=2)

# %%
sns.clustermap(pt)

# %% [markdown]
# **Regression Plots**

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',markers=['o','v'])

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,col='sex')

# %% [markdown]
# **Other Plots**

# %%
iris=sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
g=sns.PairGrid(iris)
g.map_diag(sns.distplot)
g.map_upper(plt.scatter)
g.map_lower(sns.kdeplot)

# %%
plt.figure(figsize=(5,5))
sns.countplot(x='sex',data=tips)
